# %% [markdown]
# # Many Time Pad
#
# Let us see what goes wrong when a stream cipher key is used more than once. Below are eleven hex-encoded ciphertexts that are the result of encrypting eleven plaintexts with a stream cipher, all with the same stream cipher key. Your goal is to decrypt the last ciphertext, and submit the secret message within it as solution.
#
# Hint: XOR the ciphertexts together, and consider what happens when a space is XORed with a character in [a-zA-Z].
#
# ciphertext #1:
#
# 
#
# ciphertext #2:
#
# 234c02ecbbfbafa3ed18510abd11fa724fcda2018a1a8342cf064bbde548b12b07df44ba7191d9606ef4081ffde5ad46a5069d9f7f543bedb9c861bf29c7e205132eda9382b0bc2c5c4b45f919cf3a9f1cb74151f6d551f4480c82b2cb24cc5b028aa76eb7b4ab24171ab3cdadb8356f
#
# ciphertext #3:
#
# 32510ba9a7b2bba9b8005d43a304b5714cc0bb0c8a34884dd91304b8ad40b62b07df44ba6e9d8a2368e51d04e0e7b207b70b9b8261112bacb6c866a232dfe257527dc29398f5f3251a0d47e503c66e935de81230b59b7afb5f41afa8d661cb
#
# ciphertext #4:
#
# 
#
# ciphertext #5:
#
# 3f561ba9adb4b6ebec54424ba317b564418fac0dd35f8c08d31a1fe9e24fe56808c213f17c81d9607cee021dafe1e001b21ade877a5e68bea88d61b93ac5ee0d562e8e9582f5ef375f0a4ae20ed86e935de81230b59b73fb4302cd95d770c65b40aaa065f2a5e33a5a0bb5dcaba43722130f042f8ec85b7c2070
#
# ciphertext #6:
#
# 
#
# ciphertext #7:
#
# 
#
# ciphertext #8:
#
# 315c4eeaa8b5f8bffd11155ea506b56041c6a00c8a08854dd21a4bbde54ce56801d943ba708b8a3574f40c00fff9e00fa1439fd0654327a3bfc860b92f89ee04132ecb9298f5fd2d5e4b45e40ecc3b9d59e9417df7c95bba410e9aa2ca24c5474da2f276baa3ac325918b2daada43d6712150441c2e04f6565517f317da9d3
#
# ciphertext #9:
#
# 
#
# ciphertext #10:
#
# 466d06ece998b7a2fb1d464fed2ced7641ddaa3cc31c9941cf110abbf409ed39598005b3399ccfafb61d0315fca0a314be138a9f32503bedac8067f03adbf3575c3b8edc9ba7f537530541ab0f9f3cd04ff50d66f1d559ba520e89a2cb2a83
#
# target ciphertext (decrypt this one):
#
# 32510ba9babebbbefd001547a810e67149caee11d945cd7fc81a05e9f85aac650e9052ba6a8cd8257bf14d13e6f0a803b54fde9e77472dbff89d71b57bddef121336cb85ccb8f3315f4b52e301d16e9f52f904

# %%
msg = []

msg.append("")

msg.append("234c02ecbbfbafa3ed18510abd11fa724fcda2018a1a8342cf064bbde548b12b07df44ba7191d9606ef4081ffde5ad46a5069d9f7f543bedb9c861bf29c7e205132eda9382b0bc2c5c4b45f919cf3a9f1cb74151f6d551f4480c82b2cb24cc5b028aa76eb7b4ab24171ab3cdadb8356f")

msg.append("32510ba9a7b2bba9b8005d43a304b5714cc0bb0c8a34884dd91304b8ad40b62b07df44ba6e9d8a2368e51d04e0e7b207b70b9b8261112bacb6c866a232dfe257527dc29398f5f3251a0d47e503c66e935de81230b59b7afb5f41afa8d661cb")

msg.append("")

msg.append("3f561ba9adb4b6ebec54424ba317b564418fac0dd35f8c08d31a1fe9e24fe56808c213f17c81d9607cee021dafe1e001b21ade877a5e68bea88d61b93ac5ee0d562e8e9582f5ef375f0a4ae20ed86e935de81230b59b73fb4302cd95d770c65b40aaa065f2a5e33a5a0bb5dcaba43722130f042f8ec85b7c2070")

msg.append("")

msg.append("")

msg.append("315c4eeaa8b5f8bffd11155ea506b56041c6a00c8a08854dd21a4bbde54ce56801d943ba708b8a3574f40c00fff9e00fa1439fd0654327a3bfc860b92f89ee04132ecb9298f5fd2d5e4b45e40ecc3b9d59e9417df7c95bba410e9aa2ca24c5474da2f276baa3ac325918b2daada43d6712150441c2e04f6565517f317da9d3")

msg.append("")

msg.append("466d06ece998b7a2fb1d464fed2ced7641ddaa3cc31c9941cf110abbf409ed39598005b3399ccfafb61d0315fca0a314be138a9f32503bedac8067f03adbf3575c3b8edc9ba7f537530541ab0f9f3cd04ff50d66f1d559ba520e89a2cb2a83")

secretmsg = "32510ba9babebbbefd001547a810e67149caee11d945cd7fc81a05e9f85aac650e9052ba6a8cd8257bf14d13e6f0a803b54fde9e77472dbff89d71b57bddef121336cb85ccb8f3315f4b52e301d16e9f52f904"

# %%
import numpy as np

npm = []

for m in msg:
    npm.append(np.array(bytearray.fromhex(m)))

# %%
type(bytearray.fromhex(secretmsg))

npm[0][:100].__xor__(npm[2][:100])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-7f83066bb7b4> in <module>()
#       2
#       3
# ----> 4 npm[0][:100].__xor__(npm[2][:100])
#
# ValueError: operands could not be broadcast together with shapes (100,) (95,)

# %%
def xorarray (arr1, arr2):
    len1 = len(arr1)
    len2 = len(arr2)
    minlen = min(len1,len2)
    return arr1[:minlen].__xor__(arr2[:minlen])

# %%
xorarray(npm[0],npm[1])
# Out:
# array([ 18,  16,  76,   6,  19,  78,  87,   9,  20,  15,  16,  79,   2,
#         82,  27,  10,   4,  66,   2,  12,  77,   7,  11,  24,  79,  72,
#         21,  84,  31,   8,   0,  72,  78,  30,   2,  65,   6,  29,   6,
#         77,  84,  11,  10,   2,   2,  16,  25,  69,  16,  22,  77,  79,
#         58,   0,  83,  67,   0,  78,  67,  14,  30,  29,  10,  82,  70,
#         18,  23,  27,   1,  23,   0,  27,  14,  69,  67,  28,  12,  29,
#         22,  10,  82,  13,  17, 116,  78,  25,   6,  26,  17,  77,  14,
#         85,  23,  79,   8,  78,  84,  55,  20,   5,  11,  23,  67,  83,
#         84,  27,  72,   7,  14,   0,  14,  77], dtype=uint8)

# %%
onearray = np.array([0,0])
for m in npm:
    for n in npm:
        if not(np.array_equiv(m, n)):
            b = xorarray(m,n)
            print(b)
            onearray = np.concatenate((onearray, b))
# Out:
# [0x12 0x10 0x4c 0x6 0x13 0x4e 0x57 0x9 0x14 0xf 0x10 0x4f 0x2 0x52 0x1b 0xa
#  0x4 0x42 0x2 0xc 0x4d 0x7 0xb 0x18 0x4f 0x48 0x15 0x54 0x1f 0x8 0x0 0x48
#  0x4e 0x1e 0x2 0x41 0x6 0x1d 0x6 0x4d 0x54 0xb 0xa 0x2 0x2 0x10 0x19 0x45
#  0x10 0x16 0x4d 0x4f 0x3a 0x0 0x53 0x43 0x0 0x4e 0x43 0xe 0x1e 0x1d 0xa
#  0x52 0x46 0x12 0x17 0x1b 0x1 0x17 0x0 0x1b 0xe 0x45 0x43 0x1c 0xc 0x1d
#  0x16 0xa 0x52 0xd 0x11 0x74 0x4e 0x19 0x6 0x1a 0x11 0x4d 0xe 0x55 0x17
#  0x4f 0x8 0x4e 0x54 0x37 0x14 0x5 0xb 0x17 0x43 0x53 0x54 0x1b 0x48 0x7 0xe
#  0x0 0xe 0x4d]
# [0x3 0xd 0x45 0x43 0xf 0x7 0x43 0x3 0x41 0x17 0x1c 0x6 0x1c 0x47 0x54 0x9
#  0x7 0x4f 0x1b 0x1 0x4d 0x29 0x0 0x17 0x59 0x5d 0x5a 0x51 0x57 0x0 0x7 0x48
#  0x4e 0x1e 0x2 0x41 0x19 0x11 0x55 0xe 0x52 0x1a 0x1f 0x19 0x1f 0x12 0x6
#  0x4 0x2 0x1b 0x4b 0x52 0x24 0x45 0x43 0x2 0xf 0x4e 0x44 0x13 0x5 0x5 0xa
#  0x0 0x7 0x41 0xf 0x1b 0x1b 0x52 0x4f 0x12 0x48 0x3 0x41 0x0 0x16 0x14 0x42
# ...

# %%
print(onearray)

print(len(onearray))
onearray.flatten()
unique, counts = np.unique(onearray, return_counts=True)
frequencies = dict(zip(unique, counts))

import operator
sorted_d = sorted(frequencies.items(), key=operator.itemgetter(1))
# Out:
# [0x0 0x0 0x12 ..., 0xa 0x5d 0xc]
# 10478

# %%
print(sorted_d[-10:-1])
# Out:
# [(82, 252), (23, 256), (27, 260), (17, 270), (84, 282), (79, 296), (1, 298), (6, 336), (69, 414)]

# %%
import sys

def strxor(a, b):     # xor two strings of different lengths
    if len(a) > len(b):
       return "".join([chr(ord(x) ^ ord(y)) for (x, y) in zip(a[:len(b)], b)])
    else:
       return "".join([chr(ord(x) ^ ord(y)) for (x, y) in zip(a, b[:len(a)])])

def random(size=16):
    return open("/dev/urandom").read(size)

def encrypt(key, msg):
    c = strxor(key, msg)
    print
    print (c.encode('hex'))
    return c

# %%
print (strxor("monkey", random()))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-63-a5cde9a3cb4f> in <module>()
# ----> 1 print (strxor("monkey", random()))
#
# <ipython-input-11-efa367d10be2> in random(size)
#       8
#       9 def random(size=16):
# ---> 10     return open("/dev/urandom").read(size)
#      11
#      12 def encrypt(key, msg):
#
# /anaconda3/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc0 in position 2: invalid start byte

# %% [markdown]
# Letter	Count	 	Letter	Frequency
# E	21912	 	E	12.02
# T	16587	 	T	9.10
# A	14810	 	A	8.12
# O	14003	 	O	7.68
# I	13318	 	I	7.31
# N	12666	 	N	6.95
# S	11450	 	S	6.28
# R	10977	 	R	6.02
# H	10795	 	H	5.92
# D	7874	 	D	4.32
# L	7253	 	L	3.98
# U	5246	 	U	2.88
# C	4943	 	C	2.71
# M	4761	 	M	2.61
# F	4200	 	F	2.30
# Y	3853	 	Y	2.11
# W	3819	 	W	2.09
# G	3693	 	G	2.03
# P	3316	 	P	1.82
# B	2715	 	B	1.49
# V	2019	 	V	1.11
# K	1257	 	K	0.69
# X	315	 	X	0.17
# Q	205	 	Q	0.11
# J	188	 	J	0.10
# Z	128	 	Z	0.07

# %%
freq = {'e' : 0.1202, 't' : 0.0910, 'a' : 0.0812, 'o' : 0.0768, 'i' : 0.0731, 'n' : 0.0695, 's' : 0.0628, 'r' : 0.0602,
        'h' : 0.0592, 'd' : 0.0432, 'l' : 0.0398, 'u' : 0.0288, 'c' : 0.0271, 'm' : 0.0261, 'f' : 0.0230, 'y' : 0.0211,
        'w' : 0.0209, 'g' : 0.0203, 'p' : 0.0182, 'b' : 0.0149, 'v' : 0.0111, 'k' : 0.0069, 'x' : 0.0017, 'q' : 0.0011,
        'j' : 0.0010, 'z' : 0.0007}

# %%
print(strxor(secretmsg,msg[1]))
# Out:
# PR
# WQ

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
print(format(ord(' '), '02x'))
# Out:
# 20

# %%
def printhex(ch):
    print(format(ord(ch), '02x'))

# %%
printhex("a")
# Out:
# 61

# %%
printhex("A")
# Out:
# 41

# %%
ord("E") ^ ord("T")
# Out:
# 17

# %%
ord("e") ^ ord("t")
# Out:
# 17

# %%
0x31
# Out:
# 49

# %%
print(chr(0x41 ^ 0x20))
# Out:
# a

# %% [markdown]
# xoring with space (0x20) yields opposite case

# %%
bytes.fromhex(secretmsg)[1]
# Out:
# 81

# %%
ord('a')
# Out:
# 97

# %%
printhex('Z')
# Out:
# 5a

# %%
0x41 ^ 0x62
# Out:
# 35

# %%
0x41 ^ 0x7a
# Out:
# 59

# %%
# Lowercase letters A=0x61, Z=0x7a
for a1 in range(0x41,0x5a):
    for a2 in range(0x61,0x7a):
        print(format(a1^a2, '02x'))
# Out:
# 20
# 23
# 22
# 25
# 24
# 27
# 26
# 29
# 28
# 2b
# 2a
# 2d
# 2c
# 2f
# 2e
# 31
# 30
# 33
# 32
# 35
# 34
# 37
# 36
# 39
# 38
# 23
# 20
# 21
# 26
# 27
# 24
# 25
# 2a
# 2b
# 28
# 29
# 2e
# 2f
# 2c
# 2d
# 32
# 33
# 30
# 31
# 36
# 37
# 34
# 35
# 3a
# 3b
# 22
# 21
# 20
# 27
# 26
# 25
# 24
# 2b
# 2a
# 29
# 28
# 2f
# 2e
# 2d
# 2c
# 33
# 32
# 31
# 30
# 37
# 36
# 35
# 34
# 3b
# 3a
# 25
# 26
# 27
# 20
# 21
# 22
# 23
# 2c
# 2d
# 2e
# 2f
# 28
# 29
# 2a
# 2b
# 34
# 35
# 36
# 37
# 30
# 31
# 32
# 33
# 3c
# 3d
# 24
# 27
# 26
# 21
# 20
# 23
# 22
# 2d
# 2c
# 2f
# 2e
# 29
# 28
# 2b
# 2a
# 35
# 34
# 37
# 36
# 31
# 30
# 33
# 32
# 3d
# 3c
# 27
# 24
# 25
# 22
# 23
# 20
# 21
# 2e
# 2f
# 2c
# 2d
# 2a
# 2b
# 28
# 29
# 36
# 37
# 34
# 35
# 32
# 33
# 30
# 31
# 3e
# 3f
# 26
# 25
# 24
# 23
# 22
# 21
# 20
# 2f
# 2e
# 2d
# 2c
# 2b
# 2a
# 29
# 28
# 37
# 36
# 35
# 34
# 33
# 32
# 31
# 30
# 3f
# 3e
# 29
# 2a
# 2b
# 2c
# 2d
# 2e
# 2f
# 20
# 21
# 22
# 23
# 24
# 25
# 26
# 27
# 38
# 39
# 3a
# 3b
# 3c
# 3d
# 3e
# 3f
# 30
# 31
# ...

# %% [markdown]
# Uppercase letters A=0x41, Z=0x5A
# Lowercase letters a=0x61, z=0x7a
# Space = 0x20, Period = 0x2e, Comma = 0x2c, Quote = 0x22
# The only way to get above 0x3f is to have a letter xor'ed with space, comma, quote or period

# %%
# Space = 0x20
print(format(0x20^0x7a, '02x'))
# Out:
# 5a

# %%
print(format(ord('"'), '02x'))
print(0x7a)
print(chr(0x55))
# Out:
# 22
# 122
# U

# %%
p1 =xorarray(npm[0],npm[1])

np.set_printoptions(formatter={'int':hex})
print(p1)
# Out:
# [0x12 0x10 0x4c 0x6 0x13 0x4e 0x57 0x9 0x14 0xf 0x10 0x4f 0x2 0x52 0x1b 0xa
#  0x4 0x42 0x2 0xc 0x4d 0x7 0xb 0x18 0x4f 0x48 0x15 0x54 0x1f 0x8 0x0 0x48
#  0x4e 0x1e 0x2 0x41 0x6 0x1d 0x6 0x4d 0x54 0xb 0xa 0x2 0x2 0x10 0x19 0x45
#  0x10 0x16 0x4d 0x4f 0x3a 0x0 0x53 0x43 0x0 0x4e 0x43 0xe 0x1e 0x1d 0xa
#  0x52 0x46 0x12 0x17 0x1b 0x1 0x17 0x0 0x1b 0xe 0x45 0x43 0x1c 0xc 0x1d
#  0x16 0xa 0x52 0xd 0x11 0x74 0x4e 0x19 0x6 0x1a 0x11 0x4d 0xe 0x55 0x17
#  0x4f 0x8 0x4e 0x54 0x37 0x14 0x5 0xb 0x17 0x43 0x53 0x54 0x1b 0x48 0x7 0xe
#  0x0 0xe 0x4d]
